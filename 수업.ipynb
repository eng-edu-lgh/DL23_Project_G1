# %% [markdown]
# <a href="https://colab.research.google.com/github/eng-edu-lgh/DL23_Project_G1/blob/main/%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Let's learn grammar!**
# ##Modals (can, should, will)

# %% [markdown]
# ###**1. What is Modal verb?**
# Look at these cartoons.
# They explains the situation needing the modal verbs to describe: find out the differences.

# %%
8
#@markdown 💠 Lecture slides (#1~6)
from IPython.display import Image

pages = "6" #@param = ["1", "2", "3", "4", "5","6"]
adds = ['https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_202352814010868.jpg',
        'https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_202352814041459.jpg',
        'https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_202352814047396.jpg',
        'https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_202352814827389.jpg',
        'https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_20235281418177.jpg',
        'https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_20235281410206.jpg']

if pages == "1":
  add = adds[0]
elif pages == "2":
  add = adds[1]
elif pages == "3":
  add = adds[2]
elif pages == "4":
  add = adds[3]
elif pages == "5":
  add = adds[4]
elif pages == "6":
  add = adds[5]
Image(url=add, width=800, height=00)
# Out:
# <img src="https://raw.githubusercontent.com/eng-edu-lgh/DL23_Project_G1/main/image/tooning_20235281410206.jpg" width="800"/>

# %% [markdown]
# ###**2. Types of Modal Verbs**
# Take a vocabulary quiz to learn meaning and usage of each modal verbs

# %%
#@markdown QUIZ code
# !pip install qrcode

import qrcode

data = "https://github.com/eng-edu-lgh/DL23_Project_G1/blob/main/codes/vocabularyquiz%20codes.ipynb"

qr = qrcode.QRCode(version=1, error_correction=qrcode.constants.ERROR_CORRECT_H, box_size=5, border=2)
qr.add_data(data)
qr.make(fit=True)

qr_image = qr.make_image(fill_color="black", back_color="white")

qr_image.show()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: qrcode in /usr/local/lib/python3.10/dist-packages (7.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qrcode) (4.5.0)
# Requirement already satisfied: pypng in /usr/local/lib/python3.10/dist-packages (from qrcode) (0.20220715.0)
# <PIL.Image.Image image mode=1 size=285x285 at 0x7F2DBE9BEB00>

# %%
#@markdown quiz
import random

vocab_dict = {
    "can": [
        "to be able to; have the ability, power, or skill to",
        "to know how to",
        "to have the power or means to",
        "to have the right or qualifications to",
        "may; have permission to"
    ],
    "should": [
        "used to indicate duty, propriety, or expediency"
    ],
    "will": [
        "may be expected or supposed to",
        "am (is, are, etc.) about or going to"
    ]
}

def quiz():
    score = 0
    questions = []
    for word, definitions in vocab_dict.items():
        for definition in definitions:
            questions.append((word, definition))
    random.shuffle(questions)
    for word, definition in questions:
        print("What is the word for this definition? '{}'".format(definition))
        answer = input("Answer: ")
        if answer.lower() == word.lower():
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The correct answer is '{}'.".format(word))
        print()
    print("Quiz complete. You scored {}/{} points.".format(score, len(questions)))

quiz()

# %% [markdown]
# ###**3. Rules of Modal verbs**
# Listen to the script and find out the rules for themselves.
# Then share with padlet. (scan the QR code below)

# %%
#@markdown 🔄
 # %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True)
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
#@markdown 🔄 Listen to the text
def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True)
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")
tts(" How do animals see the world? Take a fun quiz and see the world through the eyes of animals!Dogs can see blue and yellow. They cannot see other colors well. For example, they cannot see red. So, don't buy a red ball for your dog.  Your dog cannot see it well. Don't be sad. Dogs don't need great eyes because they have an amazing sense of smell. Hold a pencil in front of your nose. Can you see it? Of course you can. But horses can't. Their eyes are far apart. Horses have eyes on the sides of their heads. So they cannot see things right in front of their noses! But horses can almost see behind their heads. They can easily run away from their enemies. Imagine this. You are on the 10th floor. Can you see the ant on the street? Of course not. But eagles can. They are great hunters because of their wonderful eyes. They can see a rabbit up to 3.2 kilometers away. Isn't it amazing? Also, eagles have really big eyes. Their eyes make up 50 percent of their heads!")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown padlet qr code
import qrcode

data = "https://padlet.com/engedulgh/write-down-the-rules-ouidyd7x1wtz4nep"

qr = qrcode.QRCode(version=1, error_correction=qrcode.constants.ERROR_CORRECT_H, box_size=5, border=2)
qr.add_data(data)
qr.make(fit=True)

qr_image = qr.make_image(fill_color="black", back_color="white")

qr_image.show()
# Out:
# <PIL.Image.Image image mode=1 size=265x265 at 0x7F2DBE9BDB70>

# %% [markdown]
# ###**4. Creating Negative and Interrogative Sentences with Modal Verbs**
# Based on the rules found before, create sentences and upload them on google docs ( ask one thing to your partner )

# %% [markdown]
# google docs 링크 삽입

# %%
#@markdown Go to google sheets
import qrcode

data = "https://docs.google.com/spreadsheets/d/1h_nERv9yWiArpJ379O7wn94AZnpEewW8pHk3HuQIb7g/edit?usp=drivesdk"

qr = qrcode.QRCode(version=1, error_correction=qrcode.constants.ERROR_CORRECT_H, box_size=5, border=2)
qr.add_data(data)
qr.make(fit=True)

qr_image = qr.make_image(fill_color="black", back_color="white")

qr_image.show()
# Out:
# <PIL.Image.Image image mode=1 size=305x305 at 0x7F2DB14F5690>

# %% [markdown]
# ###**5. Comprehension test**
# wordwall - unjumble to check

# %%
#@markdown Go to google sheets
import qrcode

data = "https://wordwall.net/resource/57210559"

qr = qrcode.QRCode(version=1, error_correction=qrcode.constants.ERROR_CORRECT_H, box_size=5, border=2)
qr.add_data(data)
qr.make(fit=True)

qr_image = qr.make_image(fill_color="black", back_color="white")

qr_image.show()
# Out:
# <PIL.Image.Image image mode=1 size=205x205 at 0x7F2DB14F7250>
